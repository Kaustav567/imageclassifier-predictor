# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib
import sklearn

print("TensorFlow version:", tf.__version__)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("scikit-learn version:", sklearn.__version__)
# Out:
# TensorFlow version: 2.13.0
# NumPy version: 1.24.3
# Pandas version: 2.0.3
# Matplotlib version: 3.7.5
# scikit-learn version: 1.3.2

# %%
import tensorflow as tf

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Print dataset shapes
print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 30s 0us/step
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 1)

# %%
# Normalize the pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32')/255.0

# %%
from tensorflow.keras.utils import to_categorical

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test,10)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Fit the generator to the training data
datagen.fit(x_train)

# %%
from sklearn.model_selection import train_test_split

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

print(f"x_train shape: {x_train.shape}")
print(f"x_val shape: {x_val.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# x_train shape: (40000, 32, 32, 3)
# x_val shape: (10000, 32, 32, 3)
# y_train shape: (40000, 10)
# y_val shape: (10000, 10)

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize the pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Fit the generator to the training data
datagen.fit(x_train)

# Split the training data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Print dataset shapes
print(f"x_train shape: {x_train.shape}")
print(f"x_val shape: {x_val.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: (40000, 32, 32, 3)
# x_val shape: (10000, 32, 32, 3)
# y_train shape: (40000, 10)
# y_val shape: (10000, 10)
# x_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 356810 (1.36 MB)
# Trainable params: 356810 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=100,
                    validation_data=(x_val, y_val),
                    steps_per_epoch=len(x_train)//32)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 31s 24ms/step - loss: 1.7720 - accuracy: 0.3435 - val_loss: 1.3810 - val_accuracy: 0.4974
# Epoch 2/100
# 1250/1250 [==============================] - 39s 31ms/step - loss: 1.4493 - accuracy: 0.4796 - val_loss: 1.2615 - val_accuracy: 0.5372
# Epoch 3/100
# 1250/1250 [==============================] - 41s 32ms/step - loss: 1.3210 - accuracy: 0.5305 - val_loss: 1.1287 - val_accuracy: 0.5956
# Epoch 4/100
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.2417 - accuracy: 0.5652 - val_loss: 1.1068 - val_accuracy: 0.6111
# Epoch 5/100
# 1250/1250 [==============================] - 40s 32ms/step - loss: 1.1843 - accuracy: 0.5861 - val_loss: 0.9689 - val_accuracy: 0.6541
# Epoch 6/100
# 1250/1250 [==============================] - 39s 32ms/step - loss: 1.1341 - accuracy: 0.6042 - val_loss: 0.9751 - val_accuracy: 0.6611
# Epoch 7/100
# 1250/1250 [==============================] - 45s 36ms/step - loss: 1.0879 - accuracy: 0.6216 - val_loss: 0.9679 - val_accuracy: 0.6573
# Epoch 8/100
# 1250/1250 [==============================] - 47s 38ms/step - loss: 1.0588 - accuracy: 0.6306 - val_loss: 0.9374 - val_accuracy: 0.6706
# Epoch 9/100
# 1250/1250 [==============================] - 47s 37ms/step - loss: 1.0400 - accuracy: 0.6426 - val_loss: 0.8760 - val_accuracy: 0.6913
# Epoch 10/100
# 1250/1250 [==============================] - 49s 39ms/step - loss: 1.0143 - accuracy: 0.6498 - val_loss: 0.9242 - val_accuracy: 0.6823
# Epoch 11/100
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.9907 - accuracy: 0.6612 - val_loss: 0.8951 - val_accuracy: 0.6870
# Epoch 12/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.9686 - accuracy: 0.6673 - val_loss: 0.8279 - val_accuracy: 0.7102
# Epoch 13/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.9546 - accuracy: 0.6723 - val_loss: 0.8165 - val_accuracy: 0.7115
# Epoch 14/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.9415 - accuracy: 0.6739 - val_loss: 0.7821 - val_accuracy: 0.7275
# Epoch 15/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.9185 - accuracy: 0.6826 - val_loss: 0.8303 - val_accuracy: 0.7131
# Epoch 16/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.9144 - accuracy: 0.6862 - val_loss: 0.7904 - val_accuracy: 0.7283
# Epoch 17/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.9043 - accuracy: 0.6906 - val_loss: 0.8531 - val_accuracy: 0.7037
# Epoch 18/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8906 - accuracy: 0.6962 - val_loss: 0.7489 - val_accuracy: 0.7409
# Epoch 19/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.8854 - accuracy: 0.6963 - val_loss: 0.7861 - val_accuracy: 0.7332
# Epoch 20/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.8695 - accuracy: 0.7011 - val_loss: 0.7670 - val_accuracy: 0.7392
# Epoch 21/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8619 - accuracy: 0.7066 - val_loss: 0.7471 - val_accuracy: 0.7450
# Epoch 22/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8528 - accuracy: 0.7044 - val_loss: 0.7175 - val_accuracy: 0.7521
# Epoch 23/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8450 - accuracy: 0.7113 - val_loss: 0.8618 - val_accuracy: 0.7149
# Epoch 24/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8385 - accuracy: 0.7143 - val_loss: 0.7105 - val_accuracy: 0.7571
# Epoch 25/100
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.8255 - accuracy: 0.7145 - val_loss: 0.7870 - val_accuracy: 0.7379
# Epoch 26/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8253 - accuracy: 0.7164 - val_loss: 0.7206 - val_accuracy: 0.7508
# Epoch 27/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.8127 - accuracy: 0.7214 - val_loss: 0.7477 - val_accuracy: 0.7433
# Epoch 28/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.8067 - accuracy: 0.7240 - val_loss: 0.8507 - val_accuracy: 0.7201
# Epoch 29/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.8015 - accuracy: 0.7262 - val_loss: 0.7439 - val_accuracy: 0.7536
# Epoch 30/100
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.7939 - accuracy: 0.7265 - val_loss: 0.7059 - val_accuracy: 0.7618
# Epoch 31/100
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.7953 - accuracy: 0.7293 - val_loss: 0.7000 - val_accuracy: 0.7611
# Epoch 32/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7912 - accuracy: 0.7301 - val_loss: 0.7239 - val_accuracy: 0.7521
# Epoch 33/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.7771 - accuracy: 0.7345 - val_loss: 0.7551 - val_accuracy: 0.7502
# Epoch 34/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.7768 - accuracy: 0.7348 - val_loss: 0.7010 - val_accuracy: 0.7657
# Epoch 35/100
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.7734 - accuracy: 0.7374 - val_loss: 0.7381 - val_accuracy: 0.7483
# Epoch 36/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7708 - accuracy: 0.7368 - val_loss: 0.7231 - val_accuracy: 0.7536
# Epoch 37/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7635 - accuracy: 0.7378 - val_loss: 0.7050 - val_accuracy: 0.7641
# Epoch 38/100
# 1250/1250 [==============================] - 70s 56ms/step - loss: 0.7558 - accuracy: 0.7425 - val_loss: 0.6774 - val_accuracy: 0.7721
# Epoch 39/100
# 1250/1250 [==============================] - 68s 55ms/step - loss: 0.7535 - accuracy: 0.7439 - val_loss: 0.7038 - val_accuracy: 0.7603
# Epoch 40/100
# 1250/1250 [==============================] - 67s 54ms/step - loss: 0.7477 - accuracy: 0.7452 - val_loss: 0.7500 - val_accuracy: 0.7524
# Epoch 41/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.7439 - accuracy: 0.7476 - val_loss: 0.6945 - val_accuracy: 0.7717
# Epoch 42/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7366 - accuracy: 0.7458 - val_loss: 0.7317 - val_accuracy: 0.7648
# Epoch 43/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7382 - accuracy: 0.7444 - val_loss: 0.6926 - val_accuracy: 0.7673
# Epoch 44/100
# 1250/1250 [==============================] - 68s 54ms/step - loss: 0.7382 - accuracy: 0.7483 - val_loss: 0.6550 - val_accuracy: 0.7761
# Epoch 45/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7274 - accuracy: 0.7503 - val_loss: 0.6658 - val_accuracy: 0.7765
# Epoch 46/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7254 - accuracy: 0.7538 - val_loss: 0.6717 - val_accuracy: 0.7745
# Epoch 47/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7251 - accuracy: 0.7547 - val_loss: 0.6737 - val_accuracy: 0.7781
# Epoch 48/100
# 1250/1250 [==============================] - 66s 53ms/step - loss: 0.7202 - accuracy: 0.7548 - val_loss: 0.6972 - val_accuracy: 0.7708
# Epoch 49/100
# 1250/1250 [==============================] - 65s 52ms/step - loss: 0.7217 - accuracy: 0.7526 - val_loss: 0.6906 - val_accuracy: 0.7759
# Epoch 50/100
# 1250/1250 [==============================] - 67s 53ms/step - loss: 0.7179 - accuracy: 0.7538 - val_loss: 0.7191 - val_accuracy: 0.7605
# Epoch 51/100
# 1250/1250 [==============================] - 46s 37ms/step - loss: 0.7066 - accuracy: 0.7564 - val_loss: 0.7079 - val_accuracy: 0.7702
# Epoch 52/100
# 1250/1250 [==============================] - 40s 32ms/step - loss: 0.7098 - accuracy: 0.7553 - val_loss: 0.7086 - val_accuracy: 0.7675
# Epoch 53/100
# 1250/1250 [==============================] - 42s 33ms/step - loss: 0.7101 - accuracy: 0.7570 - val_loss: 0.6676 - val_accuracy: 0.7777
# Epoch 54/100
# 1250/1250 [==============================] - 41s 33ms/step - loss: 0.6995 - accuracy: 0.7628 - val_loss: 0.6633 - val_accuracy: 0.7740
# Epoch 55/100
# 1250/1250 [==============================] - 43s 34ms/step - loss: 0.7094 - accuracy: 0.7606 - val_loss: 0.6997 - val_accuracy: 0.7714
# Epoch 56/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6950 - accuracy: 0.7612 - val_loss: 0.6657 - val_accuracy: 0.7808
# Epoch 57/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.7003 - accuracy: 0.7579 - val_loss: 0.6586 - val_accuracy: 0.7789
# Epoch 58/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6892 - accuracy: 0.7630 - val_loss: 0.6514 - val_accuracy: 0.7810
# Epoch 59/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6902 - accuracy: 0.7640 - val_loss: 0.6504 - val_accuracy: 0.7832
# Epoch 60/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6947 - accuracy: 0.7634 - val_loss: 0.7049 - val_accuracy: 0.7712
# Epoch 61/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6889 - accuracy: 0.7654 - val_loss: 0.6877 - val_accuracy: 0.7747
# Epoch 62/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6897 - accuracy: 0.7657 - val_loss: 0.6706 - val_accuracy: 0.7822
# Epoch 63/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6919 - accuracy: 0.7624 - val_loss: 0.6849 - val_accuracy: 0.7730
# Epoch 64/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6856 - accuracy: 0.7653 - val_loss: 0.6548 - val_accuracy: 0.7877
# Epoch 65/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6844 - accuracy: 0.7646 - val_loss: 0.6455 - val_accuracy: 0.7841
# Epoch 66/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6844 - accuracy: 0.7697 - val_loss: 0.7029 - val_accuracy: 0.7660
# Epoch 67/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6837 - accuracy: 0.7650 - val_loss: 0.6688 - val_accuracy: 0.7757
# Epoch 68/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6841 - accuracy: 0.7682 - val_loss: 0.6834 - val_accuracy: 0.7724
# Epoch 69/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6759 - accuracy: 0.7689 - val_loss: 0.7374 - val_accuracy: 0.7666
# Epoch 70/100
# 1250/1250 [==============================] - 37s 29ms/step - loss: 0.6823 - accuracy: 0.7683 - val_loss: 0.6522 - val_accuracy: 0.7816
# Epoch 71/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6721 - accuracy: 0.7725 - val_loss: 0.7163 - val_accuracy: 0.7694
# Epoch 72/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6666 - accuracy: 0.7718 - val_loss: 0.7073 - val_accuracy: 0.7655
# Epoch 73/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6705 - accuracy: 0.7706 - val_loss: 0.6924 - val_accuracy: 0.7719
# Epoch 74/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6677 - accuracy: 0.7728 - val_loss: 0.7040 - val_accuracy: 0.7730
# Epoch 75/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6739 - accuracy: 0.7695 - val_loss: 0.6504 - val_accuracy: 0.7859
# Epoch 76/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6702 - accuracy: 0.7722 - val_loss: 0.6636 - val_accuracy: 0.7791
# Epoch 77/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6624 - accuracy: 0.7748 - val_loss: 0.6657 - val_accuracy: 0.7761
# Epoch 78/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6631 - accuracy: 0.7772 - val_loss: 0.6706 - val_accuracy: 0.7773
# Epoch 79/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6668 - accuracy: 0.7729 - val_loss: 0.6532 - val_accuracy: 0.7841
# Epoch 80/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6558 - accuracy: 0.7772 - val_loss: 0.6894 - val_accuracy: 0.7734
# Epoch 81/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6596 - accuracy: 0.7770 - val_loss: 0.7242 - val_accuracy: 0.7655
# Epoch 82/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6585 - accuracy: 0.7770 - val_loss: 0.6847 - val_accuracy: 0.7805
# Epoch 83/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6525 - accuracy: 0.7786 - val_loss: 0.6382 - val_accuracy: 0.7879
# Epoch 84/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6548 - accuracy: 0.7778 - val_loss: 0.6843 - val_accuracy: 0.7779
# Epoch 85/100
# 1250/1250 [==============================] - 39s 31ms/step - loss: 0.6444 - accuracy: 0.7806 - val_loss: 0.6669 - val_accuracy: 0.7846
# Epoch 86/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6500 - accuracy: 0.7792 - val_loss: 0.6968 - val_accuracy: 0.7768
# Epoch 87/100
# 1250/1250 [==============================] - 37s 29ms/step - loss: 0.6615 - accuracy: 0.7739 - val_loss: 0.7042 - val_accuracy: 0.7680
# Epoch 88/100
# 1250/1250 [==============================] - 39s 31ms/step - loss: 0.6525 - accuracy: 0.7768 - val_loss: 0.6917 - val_accuracy: 0.7711
# Epoch 89/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6506 - accuracy: 0.7778 - val_loss: 0.7013 - val_accuracy: 0.7743
# Epoch 90/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6462 - accuracy: 0.7796 - val_loss: 0.7253 - val_accuracy: 0.7743
# Epoch 91/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6473 - accuracy: 0.7795 - val_loss: 0.6448 - val_accuracy: 0.7902
# Epoch 92/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6474 - accuracy: 0.7789 - val_loss: 0.6481 - val_accuracy: 0.7894
# Epoch 93/100
# 1250/1250 [==============================] - 37s 30ms/step - loss: 0.6452 - accuracy: 0.7802 - val_loss: 0.6424 - val_accuracy: 0.7882
# Epoch 94/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6430 - accuracy: 0.7816 - val_loss: 0.6995 - val_accuracy: 0.7767
# Epoch 95/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6418 - accuracy: 0.7812 - val_loss: 0.6583 - val_accuracy: 0.7894
# Epoch 96/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6467 - accuracy: 0.7786 - val_loss: 0.6616 - val_accuracy: 0.7871
# Epoch 97/100
# 1250/1250 [==============================] - 39s 31ms/step - loss: 0.6415 - accuracy: 0.7834 - val_loss: 0.6681 - val_accuracy: 0.7804
# Epoch 98/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6382 - accuracy: 0.7807 - val_loss: 0.6729 - val_accuracy: 0.7861
# Epoch 99/100
# 1250/1250 [==============================] - 38s 30ms/step - loss: 0.6380 - accuracy: 0.7833 - val_loss: 0.7667 - val_accuracy: 0.7573
# Epoch 100/100
# 1250/1250 [==============================] - 38s 31ms/step - loss: 0.6458 - accuracy: 0.7827 - val_loss: 0.6531 - val_accuracy: 0.7885

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6708 - accuracy: 0.7845
# Test accuracy: 0.784500002861023

# %%
from tensorflow.keras.models import load_model

# Save the model
model.save('imgclassifier.keras')

# Load the model
model = load_model('imgclassifier.keras')

# Print the model summary to verify it has been loaded correctly
model.summary()

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy after loading the model: {test_accuracy}')
